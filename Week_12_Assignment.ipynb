# %% [markdown]
# # Week 12 Assignment
#
# ### The New York Times web site provides a rich set of APIs, as described here:
#   http://developer.nytimes.com/docs
# You’ll need to start by signing up for an API key.
# Your task is to choose one of the New York Times APIs, construct an interface in
# Python
#  to read in the JSON d
# ata, and
# transform it in
# to a
#  pandas
#  DataF
# rame.

# %%
import pandas as pd
import json
import urllib.request
from pandas.io.json import json_normalize

# %% [markdown]
# Read as JSON with the API key provided for movie reviews.

# %%
api_key = 'bc47514ff8c74b269354bcecbbf4cacf'
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'
string = url+'&api-key='+api_key

response = str(urllib.request.urlopen(string).read(), 'utf-8')

# %% [markdown]
# The data will be read into a dataframe with pandas.

# %%
movies = pd.read_json(response)
movies
# Out:
#    status                                          copyright  has_more  \
# 0      OK  Copyright (c) 2018 The New York Times Company....      True
# 1      OK  Copyright (c) 2018 The New York Times Company....      True
# 2      OK  Copyright (c) 2018 The New York Times Company....      True
# 3      OK  Copyright (c) 2018 The New York Times Company....      True
# 4      OK  Copyright (c) 2018 The New York Times Company....      True
# 5      OK  Copyright (c) 2018 The New York Times Company....      True
# 6      OK  Copyright (c) 2018 The New York Times Company....      True
# 7      OK  Copyright (c) 2018 The New York Times Company....      True
# 8      OK  Copyright (c) 2018 The New York Times Company....      True
# 9      OK  Copyright (c) 2018 The New York Times Company....      True
# 10     OK  Copyright (c) 2018 The New York Times Company....      True
# 11     OK  Copyright (c) 2018 The New York Times Company....      True
# ...

# %% [markdown]
# The column for results is unreadable in its current form and must be adjusted with json_normalize to be of use to the end user.

# %%
data = json.loads(response)
movies = json_normalize(data['results'])
movies.sort_values(by=["display_title"], ascending=False)
# Out:
#                  byline  critics_pick         date_updated  \
# 11           A.O. SCOTT             0  2018-11-18 17:44:20
# 16       KEN JAWOROWSKI             1  2018-11-16 17:44:01
# 8   JEANNETTE CATSOULIS             0  2018-11-18 17:44:20
# 12          BILGE EBIRI             0  2018-11-18 17:44:19
# 5           GLENN KENNY             0  2018-11-18 17:44:21
# 10  JEANNETTE CATSOULIS             0  2018-11-18 17:44:20
# 17           A.O. SCOTT             1  2018-11-18 17:44:14
# 13       BEN KENIGSBERG             1  2018-11-16 17:44:01
# 19          BILGE EBIRI             0  2018-11-18 17:44:18
# 2        BEN KENIGSBERG             0  2018-11-18 17:44:22
# 15  JEANNETTE CATSOULIS             1  2018-11-08 12:04:07
# 6           BILGE EBIRI             0  2018-11-18 17:44:21
# 3           GLENN KENNY             0  2018-11-18 17:44:22
# 7        BEN KENIGSBERG             0  2018-11-18 17:44:21
# 4           GLENN KENNY             0  2018-11-18 17:44:22
# ...
